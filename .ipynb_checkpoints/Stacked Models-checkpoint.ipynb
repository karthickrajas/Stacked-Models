# %% [markdown]
# ### Importing all necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats
from scipy.stats import norm, skew

#Battery of test 

from scipy.stats import shapiro
from scipy.stats import anderson
from scipy.stats import kstest

#All models

from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb


# %matplotlib inline

# %% [markdown]
# ### All sub-process

# %%
color = sns.color_palette()
sns.set_style('whitegrid')

#Function for ignoring warnings
def ignore_warning(*args, **kwargs):
    pass

warnings.warn = ignore_warning

pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %% [markdown]
# ### Importing data and preliminary analysis

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL       65.000     8450   Pave   NaN      Reg
# 1   2          20       RL       80.000     9600   Pave   NaN      Reg
# 2   3          60       RL       68.000    11250   Pave   NaN      IR1
# 3   4          70       RL       60.000     9550   Pave   NaN      IR1
# 4   5          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#check the numbers of samples and features
print("The train data size before dropping Id feature is : {} ".format(train.shape))
print("The test data size before dropping Id feature is : {} ".format(test.shape))

#Save the 'Id' column
train_ID = train['Id']
test_ID = test['Id']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(test.shape))
# Out:
# The train data size before dropping Id feature is : (1460, 81)
# The test data size before dropping Id feature is : (1459, 80)
#
# The train data size after dropping Id feature is : (1460, 80)
# The test data size after dropping Id feature is : (1459, 79)

# %% [markdown]
# #### Outlier processing

# %%
g = sns.jointplot(x='GrLivArea',y='SalePrice',data=train,color='green')
g.plot(sns.regplot, sns.distplot)
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Deleting outlier ( Not recommended )
#
# #Deleting outliers
# train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)
#
# #Check the graphic again
# fig, ax = plt.subplots()
# ax.scatter(train['GrLivArea'], train['SalePrice'])
# plt.ylabel('SalePrice', fontsize=13)
# plt.xlabel('GrLivArea', fontsize=13)
# plt.show()

# %% [markdown]
# #### Target variable analysis

# %%
#function for nomality test

def normality_test(x):
    shapiro_stat,shapiro_pvalue = shapiro(x)
    anderson_stat,anderson_pvalue,anderson_critical = anderson(x)
    kstest_stat,kstest_pvalue = kstest(x,cdf ='norm')
    data = {'shapiro': [shapiro_stat, shapiro_pvalue , 'Nan'], 'anderson': [anderson_stat, anderson_pvalue, anderson_critical],'kstest':[kstest_stat,kstest_pvalue,"Nan"]}
    normality_df = pd.DataFrame.from_dict(data, orient='index', columns=['statistic','P-value','critical_values'])
    return normality_df

# %%
#function for fitting a normal curve for examination
def feature_analysis(x,name):
    sns.distplot(x , fit=norm)
    # Get the fitted parameters used by the function
    (mu, sigma) = norm.fit(x)
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

    #Now plot the distribution
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],loc='best')
    plt.ylabel('Frequency')
    plt.title(name)

    #Get also the QQ-plot
    fig = plt.figure()
    res = stats.probplot(x, plot=plt)
    plt.show()
    
    #Results from the normality tests
    print(normality_test(train.SalePrice))

# %%
feature_analysis(train.SalePrice,'SalePrice')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#  mu = 180921.20 and sigma = 79415.29
#           statistic                              P-value  \
# shapiro       0.870                                0.000
# anderson     41.692  [0.574, 0.654, 0.785, 0.916, 1.089]
# kstest        1.000                                0.000
#
#                       critical_values
# shapiro                           Nan
# anderson  [15.0, 10.0, 5.0, 2.5, 1.0]
# kstest                            Nan

# %% [markdown]
# #### Trying out Log transformation for making the response normal

# %%
#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
log_SalePrice = np.log1p(train["SalePrice"])
feature_analysis(log_SalePrice,"log_SalePrice")
# Out:
#  mu = 12.02 and sigma = 0.40
# C:\Users\Lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#           statistic                              P-value  \
# shapiro       0.870                                0.000
# anderson     41.692  [0.574, 0.654, 0.785, 0.916, 1.089]
# kstest        1.000                                0.000
#
#                       critical_values
# shapiro                           Nan
# anderson  [15.0, 10.0, 5.0, 2.5, 1.0]
# kstest                            Nan

# %% [markdown]
# ### Feature Engineering

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (2919, 79)

# %% [markdown]
# #### Missing values

# %%
def missing_values(data):    
    #print("The number of NA values in the column")
    #print(data.isna().sum())
    all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
    all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
    columndetails = []
    missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
    print(missing_data)
    f, ax = plt.subplots(figsize=(10,8))
    plt.xticks(rotation='90')
    sns.barplot(x=all_data_na.index, y=all_data_na)
    plt.xlabel('Features', fontsize=15)
    plt.ylabel('Percent of missing values', fontsize=15)
    plt.title('Percent missing data by feature', fontsize=15)

# %%
missing_values(all_data)
# Out:
#               Missing Ratio
# PoolQC               99.657
# MiscFeature          96.403
# Alley                93.217
# Fence                80.439
# FireplaceQu          48.647
# LotFrontage          16.650
# GarageQual            5.447
# GarageCond            5.447
# GarageFinish          5.447
# GarageYrBlt           5.447
# GarageType            5.379
# BsmtExposure          2.809
# BsmtCond              2.809
# BsmtQual              2.775
# BsmtFinType2          2.741
# BsmtFinType1          2.706
# MasVnrType            0.822
# MasVnrArea            0.788
# MSZoning              0.137
# BsmtFullBath          0.069
# BsmtHalfBath          0.069
# Utilities             0.069
# Functional            0.069
# Electrical            0.034
# BsmtUnfSF             0.034
# Exterior1st           0.034
# Exterior2nd           0.034
# TotalBsmtSF           0.034
# GarageArea            0.034
# GarageCars            0.034

# %% [markdown]
# ### Data Plots

# %% [markdown]
# #### Univariate plots

# %%
def univariate_plots(df):
    #Divding categorical and numerical variable
    numerical_columns = list(df.columns[df.dtypes=="int64"])
    numerical_columns = numerical_columns + list(df.columns[df.dtypes=="float64"])
    categorical_columns = list(df.columns[df.dtypes=="object"])
    print("Univariate plot on Numerical variables ., number of variables {}".format(len(numerical_columns)))
    df[numerical_columns].hist(figsize=(16,20), bins=50, xlabelsize=8, ylabelsize=8)
    plt.show()
    print("Univariate plot on Categorical variables ., number of variables {}".format(len(categorical_columns)))
    fig, axes = plt.subplots(round(len(categorical_columns) / 3), 3, figsize=(24,36))
    for i, ax in enumerate(fig.axes):
        if i < len(categorical_columns):
            ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=90)
            sns.countplot(x=df[categorical_columns[i]], alpha=0.7, data=df, ax=ax)
    fig.tight_layout()
    plt.show()

# %%
univariate_plots(all_data)
# Out:
# Univariate plot on Numerical variables ., number of variables 36
# Univariate plot on Categorical variables ., number of variables 43

# %% [markdown]
# #### Bivariate plot

# %%
def bivariate_plot(df,name):
    #Divding categorical and numerical variable
    numerical_columns = list(df.columns[df.dtypes=="int64"])
    numerical_columns = numerical_columns + list(df.columns[df.dtypes=="float64"])
    categorical_columns = list(df.columns[df.dtypes=="object"])
    fig, ax = plt.subplots(round(len(numerical_columns) / 3), 3, figsize=(24,36))
    for i, ax in enumerate(fig.axes):
        if i <= len(numerical_columns) - 1:
            sns.regplot(x=df[numerical_columns[i]],y=df[name], ax=ax)
    fig.tight_layout()
    plt.show()
    
    
    fig, ax = plt.subplots(round(len(categorical_columns) / 1), 1, figsize=(12, 30))
    for i, ax in enumerate(fig.axes):
        if i <= len(categorical_columns) - 1:
            sns.boxplot(x=df[categorical_columns[i]],y=df[name], ax=ax)
    fig.tight_layout()
    plt.show()

# %%
bivariate_plot(train,'SalePrice')
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Correlation plot

# %%
# correlation of all variables
corrmat = train.corr()
plt.subplots(figsize=(24,18))


sns.heatmap(corrmat, 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 10}, square=True);

# %%
#correlation map for highly correalted variables
corrmat = train.corr()
plt.subplots(figsize=(24,18))


sns.heatmap(corrmat[(corrmat >= 0.5) | (corrmat <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 10}, square=True);

# %%
#Further checking for co-relation
corrmat = train.corr()['SalePrice'][:-1] # -1 because the latest row is SalePrice
high_corr= corrmat[(corrmat >= 0.5) | (corrmat <= -0.4)].sort_values(ascending=False)
print("Features with high correlation \n \n", high_corr)
# Out:
# Features with high correlation
#
#  OverallQual    0.791
# GrLivArea      0.709
# GarageCars     0.640
# GarageArea     0.623
# TotalBsmtSF    0.614
# 1stFlrSF       0.606
# FullBath       0.561
# TotRmsAbvGrd   0.534
# YearBuilt      0.523
# YearRemodAdd   0.507
# Name: SalePrice, dtype: float64

# %% [markdown]
# #### Filling in NA values

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")
all_data["Alley"] = all_data["Alley"].fillna("None")
all_data["Fence"] = all_data["Fence"].fillna("None")
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
all_data = all_data.drop(['Utilities'], axis=1)
all_data["Functional"] = all_data["Functional"].fillna("Typ")
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])
all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")

# %%
#Check remaining missing values if any 
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
# Changing the type of some variables

#MSSubClass=The building class
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)


#Changing OverallCond into a categorical variable
all_data['OverallCond'] = all_data['OverallCond'].astype(str)


#Year and month sold are transformed into categorical features.
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
# process columns, apply LabelEncoder to categorical features
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[c].values)) 
    all_data[c] = lbl.transform(list(all_data[c].values))

# shape        
print('Shape all_data: {}'.format(all_data.shape))
# Out:
# Shape all_data: (2919, 78)

# %%
# Adding total sqfootage feature 
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %% [markdown]
# #### checking for skewness

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

# Check the skew of all numerical features
skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
# Out:
# Skew in numerical features:
#                 Skew
# MiscVal       21.947
# PoolArea      16.898
# LotArea       12.822
# LowQualFinSF  12.089
# 3SsnPorch     11.376
# LandSlope      4.975
# KitchenAbvGr   4.302
# BsmtFinSF2     4.146
# EnclosedPorch  4.004
# ScreenPorch    3.947

# %% [markdown]
# #### Boxcox transformation

# %% [markdown]
# ##### Boxcox transformation of 1+x
# ##### Note that setting  λ=0  is equivalent to log1p

# %%
skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))

from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    #all_data[feat] += 1
    all_data[feat] = boxcox1p(all_data[feat], lam)
# Out:
# There are 59 skewed numerical features to Box Cox transform

# %% [markdown]
# ### Variance Inflation factor

# %% [markdown]
# #### Dummy variables

# %%
all_data = pd.get_dummies(all_data)
print(all_data.shape)
# Out:
# (2919, 221)

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %% [markdown]
# ### Modelling

# %% [markdown]
# #### cross validation
